# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup("https://www.sharesansar.com/live-trading", 'html.parser')
soup = requests.get(url)
soup
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_14628\3597715743.py:3: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   url = BeautifulSoup("https://www.sharesansar.com/live-trading", 'html.parser')
# <Response [200]>

# %%
code = BeautifulSoup(soup.text, "lxml")
code
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=no, initial-scale = 1.0, minimum-scale=1.0, maximum-scale = 1.0" name="viewport"/>
# <meta content=" sharesansar, sharesansar.com, share market, best site, nepali bazar, news, nepal, economics, politics, entertainment, business, politics, businessman, online news, real state, tax, banking, corporate, telecom,  nepse, ipo, agm, bond, Oil, Gold, profit, shareholder, NEPSE, pravhu, ILFC, Stock, exchange, citizen, nepal., loan, loss, provision,  arun, valley, kabeli,  Economy, Growth, Rate, Eid, Public, Holiday,  Mastercard, Standard, Chartered, Credit, Card, Visa, Warren, Buffett, Value, Investing,Nepal Stock Exchange (NEPSE) Live Trading Data, Floorsheet, Live Indices, Top Gainers, Top Losers, nepse, shareapp, limted, iporesult, bank , share, bank, company, promoter, bittya santha" name="keywords"/>
# <title>Live Trading - || ShareSansar ||</title>
# ...

# %%
table_code = code.table
table_code
# Out:
# <table class="table table-bordered table-striped table-hover dataTable compact" id="headFixed">
# <thead>
# <tr>
# <th width="10px">S.No</th>
# <th>Symbol</th>
# <th class="text-center">LTP</th>
# <th class="text-center">Point Change</th>
# <th class="text-center">% Change</th>
# <th class="text-center">Open</th>
# <th class="text-center">High</th>
# <th class="text-center">Low</th>
# <th class="text-center">Volume</th>
# <th class="text-center">Prev. Close</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="danger-index">
#                                         1</td>
# <td class="danger-index">
# <a href="https://www.sharesansar.com/company/aclbsl" title="ACLBSL">ACLBSL</a>
# </td>
# <td class="text-center danger-index">
#                                         1,078.91</td>
# <td class="text-center danger-index">
#                                         -21.09</td>
# <td class="text-center danger-index">
#                                         -1.92</td>
# ...

# %%
tags = table_code.find_all('tr')
tags
# Out:
# [<tr>
#  <th width="10px">S.No</th>
#  <th>Symbol</th>
#  <th class="text-center">LTP</th>
#  <th class="text-center">Point Change</th>
#  <th class="text-center">% Change</th>
#  <th class="text-center">Open</th>
#  <th class="text-center">High</th>
#  <th class="text-center">Low</th>
#  <th class="text-center">Volume</th>
#  <th class="text-center">Prev. Close</th>
#  </tr>,
#  <tr>
#  <td class="danger-index">
#                                          1</td>
#  <td class="danger-index">
#  <a href="https://www.sharesansar.com/company/aclbsl" title="ACLBSL">ACLBSL</a>
#  </td>
#  <td class="text-center danger-index">
#                                          1,078.91</td>
#  <td class="text-center danger-index">
#                                          -21.09</td>
#  <td class="text-center danger-index">
#                                          -1.92</td>
#  <td class="text-center danger-index">
#                                          1,100.00</td>
# ...

# %%
list_data = []
for i in tags:
    data = i.text
    list_data.append(data)

print(list_data)
# Out:
# ['\nS.No\nSymbol\nLTP\nPoint Change\n% Change\nOpen\nHigh\nLow\nVolume\nPrev. Close\n', '\n\n                                        1\n\nACLBSL\n\n\n                                        1,078.91\n\n                                        -21.09\n\n                                        -1.92\n\n                                        1,100.00\n\n                                        1,100.00\n\n                                        1,078.00\n\n                                        2,166.00\n\n                                        1,100.00\n', '\n\n                                        2\n\nADBL\n\n\n                                        294.44\n\n                                        -2.61\n\n                                        -0.88\n\n                                        295.00\n\n                                        296.00\n\n                                        290.00\n\n                                        37,980.00\n\n                         
# ...

# %%
cleaned_data = []
for i in list_data[1:]:
    x = (i.replace("                                        ",""))
    x = x.split('\n\n')
    x = [j .replace('\n','') for j in x]
    cleaned_data.append(x[1:])

cleaned_data
# Out:
# [['1',
#   'ACLBSL',
#   '1,078.91',
#   '-21.09',
#   '-1.92',
#   '1,100.00',
#   '1,100.00',
#   '1,078.00',
#   '2,166.00',
#   '1,100.00'],
#  ['2',
#   'ADBL',
#   '294.44',
#   '-2.61',
#   '-0.88',
#   '295.00',
#   '296.00',
#   '290.00',
#   '37,980.00',
#   '297.05'],
#  ['3',
#   'ADBLD83',
#   '1,091.00',
#   '-22.20',
#   '-1.99',
#   '1,091.00',
#   '1,091.00',
#   '1,091.00',
#   '290.00',
#   '1,113.20'],
#  ['4',
#   'AHL',
#   '664.11',
#   '-6.40',
#   '-0.95',
#   '657.20',
#   '669.90',
#   '646.90',
#   '2,357.00',
#   '670.51'],
#  ['5',
#   'AHPC',
#   '278.94',
#   '-0.84',
#   '-0.30',
#   '280.00',
#   '284.00',
#   '276.20',
#   '182,823.00',
#   '279.78'],
#  ['6',
#   'AKJCL',
#   '206.60',
#   '-0.55',
#   '-0.27',
#   '206.20',
#   '207.90',
#   '204.10',
#   '95,713.00',
#   '207.15'],
#  ['7',
#   'AKPL',
#   '240.80',
#   '-0.18',
#   '-0.07',
#   '240.00',
#   '246.00',
#   '240.00',
#   '146,728.00',
#   '240.98'],
#  ['8',
#   'ALBSL',
# ...

# %%
col = list_data[0].split('\n')[1:-1]
col
# Out:
# ['S.No',
#  'Symbol',
#  'LTP',
#  'Point Change',
#  '% Change',
#  'Open',
#  'High',
#  'Low',
#  'Volume',
#  'Prev. Close']

# %%
import pandas as pd
df = pd.DataFrame(cleaned_data,columns = col)
df
# Out:
#     S.No   Symbol       LTP Point Change % Change      Open      High  \
# 0      1   ACLBSL  1,078.91       -21.09    -1.92  1,100.00  1,100.00
# 1      2     ADBL    294.44        -2.61    -0.88    295.00    296.00
# 2      3  ADBLD83  1,091.00       -22.20    -1.99  1,091.00  1,091.00
# 3      4      AHL    664.11        -6.40    -0.95    657.20    669.90
# 4      5     AHPC    278.94        -0.84    -0.30    280.00    284.00
# ..   ...      ...       ...          ...      ...       ...       ...
# 313  314     USHL    624.00        13.00     2.13    615.00    624.00
# 314  315     USLB  2,055.22        31.23     1.54  2,000.00  2,075.00
# 315  316     VLBS    840.68        -0.01     0.00    828.00    850.00
# 316  317    VLUCL    606.19        -8.54    -1.39    607.50    614.00
# 317  318     WNLB  2,316.03       -32.61    -1.39  2,350.00  2,350.00
#
#           Low      Volume Prev. Close
# 0    1,078.00    2,166.00    1,100.00
# 1      290.00   37,980.00      297.05
# ...

# %%
df['LTP'] = [float(i.replace(',','')) for i in df['LTP']]
df['Point Change'] = [float(i) for i in df['Point Change']]
df['% Change'] = [float(i) for i in df['% Change']]
df['Open'] = [float(i.replace(',','')) for i in df['Open']]
df['High'] = [float(i.replace(',','')) for i in df['High']]
df['Low'] = [float(i.replace(',','')) for i in df['Low']]
df['Volume'] = [float(i.replace(',','')) for i in df['Volume']]
df['Prev. Close'] = [float(i.replace(',','')) for i in df['Prev. Close']]

# %%
df
# Out:
#     S.No   Symbol      LTP  Point Change  % Change    Open    High     Low  \
# 0      1   ACLBSL  1078.91        -21.09     -1.92  1100.0  1100.0  1078.0
# 1      2     ADBL   294.44         -2.61     -0.88   295.0   296.0   290.0
# 2      3  ADBLD83  1091.00        -22.20     -1.99  1091.0  1091.0  1091.0
# 3      4      AHL   664.11         -6.40     -0.95   657.2   669.9   646.9
# 4      5     AHPC   278.94         -0.84     -0.30   280.0   284.0   276.2
# ..   ...      ...      ...           ...       ...     ...     ...     ...
# 313  314     USHL   624.00         13.00      2.13   615.0   624.0   610.1
# 314  315     USLB  2055.22         31.23      1.54  2000.0  2075.0  1975.1
# 315  316     VLBS   840.68         -0.01      0.00   828.0   850.0   828.0
# 316  317    VLUCL   606.19         -8.54     -1.39   607.5   614.0   603.0
# 317  318     WNLB  2316.03        -32.61     -1.39  2350.0  2350.0  2310.0
#
#        Volume  Prev. Close
# 0      2166.0      1100.00
# ...

# %%
# !pip install plotly

# %%
import plotly.express as px
fig = px.bar(df, x='Symbol', y='Point Change')
fig.show()

# %%
# top_10_positive_change = df[df['% Change'] > 0].nlargest(10, '% Change')
top_10_positive_change = df.sort_values(by='% Change', ascending=False).head(10)
fig = px.bar(top_10_positive_change, x='Symbol', y='% Change')
fig.show()
top_10_positive_change
# Out:
#     S.No  Symbol      LTP  Point Change  % Change    Open    High     Low  \
# 70    71   GRDBL  1231.80        111.95     10.00  1142.0  1231.8  1138.0
# 37    38   CORBL  2403.80        218.44     10.00  2141.7  2403.8  2141.7
# 206  207    OMPL  1363.20        123.90     10.00  1264.0  1363.2  1264.0
# 15    16    BEDC   740.70         67.33     10.00   666.0   740.7   665.0
# 221  222    PURE   318.20         28.90      9.99   289.3   318.2   289.3
# 23    24    BPCL   531.72         39.14      7.95   495.0   535.5   493.2
# 302  303   UHEWA   602.91         43.43      7.76   550.0   613.0   550.0
# 242  243  SAPDBL   905.69         64.00      7.60   832.1   916.0   832.1
# 310  311    UPCL   454.94         27.35      6.40   428.0   461.0   422.0
# 270  271   SINDU   877.88         41.81      5.00   823.0   888.0   800.0
#
#         Volume  Prev. Close
# 70     55556.0      1119.85
# 37     29463.0      2185.36
# 206     1180.0      1239.30
# 15    103061.0       673.37
# ...

# %%
# top_10_positive_change = df[df['% Change'] > 0].nlargest(10, '% Change')
top_10_neg_change = df.sort_values(by='% Change', ascending=True).head(10)
fig = px.bar(top_10_neg_change, x='Symbol', y='% Change')
fig.show()

# %%
# top_10_positive_change = df[df['% Change'] > 0].nlargest(10, '% Change')
top_10_neg_change = df.sort_values(by='Volume', ascending=False).head(10)
fig = px.bar(top_10_neg_change, x='Symbol', y='Volume')
fig.show()

# %%
top_change = df.sort_values(by='% Change', ascending=False).head(10)
top_volume = top_change.sort_values(by='Volume', ascending=False).head(10)
fig = px.bar(top_volume, x='Symbol', y='Volume')
fig.show()

# %%
import plotly.express as px
top_10_volume = df.sort_values(by='Volume', ascending=False).head(10)
fig = px.pie(top_10_volume, values='Volume', names='Symbol', title='Top 10 Volume Analysis')
fig.show()

# %%
pwd
# Out:
# 'C:\\Users\\acer\\Python class'
